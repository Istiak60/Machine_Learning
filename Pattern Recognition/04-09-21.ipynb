# %%
print("hello python")
# Out:
# hello python

# %%
#string indexing
a="hello world!"
print(a[:6])
# Out:
# hello

# %%
print(a[2:8])
# Out:
# llo wo

# %%
#split()
x="I read in port city international University"
x=x.split()
print (x)
# Out:
# ['I', 'read', 'in', 'port', 'city', 'international', 'University']

# %%
print(a.upper())
print(a.lower())
# Out:
# HELLO WORLD!
# hello world!

# %%
#boolean
print(10>9)
# Out:
# True

# %%
def new():
  print("I love bangladesh")
new()
# Out:
# I love bangladesh

# %%
#list
lista=["a","b",1,5]
print(lista)
# Out:
# ['a', 'b', 1, 5]

# %%
#Write a function to sum all numbers of a list.
list1=[1,2,3]
def sum(abc):
 res=0;
 for z in abc:
  res+=z
 return res ;
answer=sum(list1)
print(answer)
# Out:
# 6

# %%
#assignment 1
for number in range(2000,3201):
 if(number%7==0 and number%5!=0):
  print(number)
# Out:
# 2002
# 2009
# 2016
# 2023
# 2037
# 2044
# 2051
# 2058
# 2072
# 2079
# 2086
# 2093
# 2107
# 2114
# 2121
# 2128
# 2142
# 2149
# 2156
# 2163
# 2177
# 2184
# 2191
# 2198
# 2212
# 2219
# 2226
# 2233
# 2247
# 2254
# 2261
# 2268
# 2282
# 2289
# 2296
# 2303
# 2317
# 2324
# 2331
# 2338
# 2352
# 2359
# 2366
# 2373
# 2387
# 2394
# 2401
# 2408
# 2422
# 2429
# 2436
# 2443
# 2457
# 2464
# 2471
# 2478
# 2492
# 2499
# 2506
# 2513
# 2527
# 2534
# 2541
# 2548
# 2562
# 2569
# 2576
# 2583
# 2597
# 2604
# 2611
# 2618
# 2632
# 2639
# 2646
# 2653
# 2667
# 2674
# 2681
# 2688
# 2702
# 2709
# 2716
# 2723
# 2737
# 2744
# 2751
# 2758
# 2772
# 2779
# 2786
# 2793
# 2807
# 2814
# 2821
# 2828
# 2842
# 2849
# 2856
# 2863
# 2877
# 2884
# 2891
# 2898
# 2912
# 2919
# 2926
# 2933
# 2947
# 2954
# 2961
# 2968
# 2982
# 2989
# 2996
# 3003
# 3017
# 3024
# 3031
# 3038
# 3052
# 3059
# 3066
# 3073
# 3087
# 3094
# 3101
# 3108
# 3122
# 3129
# 3136
# 3143
# 3157
# 3164
# 3171
# 3178
# 3192
# 3199

# %%
#assignment 2
for number in range(1,16):
  dic={number:number*number}
  print(dic)
# Out:
# {1: 1}
# {2: 4}
# {3: 9}
# {4: 16}
# {5: 25}
# {6: 36}
# {7: 49}
# {8: 64}
# {9: 81}
# {10: 100}
# {11: 121}
# {12: 144}
# {13: 169}
# {14: 196}
# {15: 225}

# %%
#assignment 3
x="we live in Bangladesh.we love our country"
cnt=x.count("we")
print(cnt)
# Out:
# 2

# %%
#assignment 4
list1=[10,20,30,40,10,30,40,50,100,10]
list2=[]
for i in list1:
 if i not in list2:
  list2.append(i)
print(list2)
# Out:
# [10, 20, 30, 40, 50, 100]
