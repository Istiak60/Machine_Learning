# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-7af94f91-8c26-4ec7-9cdd-130143c6a093" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7af94f91-8c26-4ec7-9cdd-130143c6a093">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving credit card taiwan svm algorithm.csv to credit card taiwan svm algorithm.csv

# %%
import io
import pandas as pd
df=pd.read_csv(io.BytesIO(upload['credit card taiwan svm algorithm.csv']))

# %%
df
# Out:
#           ID  LIMIT_BAL  ...  PAY_AMT6  default.payment.next.month
# 0          1    20000.0  ...       0.0                           1
# 1          2   120000.0  ...    2000.0                           1
# 2          3    90000.0  ...    5000.0                           0
# 3          4    50000.0  ...    1000.0                           0
# 4          5    50000.0  ...     679.0                           0
# ...      ...        ...  ...       ...                         ...
# 29995  29996   220000.0  ...    1000.0                           0
# 29996  29997   150000.0  ...       0.0                           0
# 29997  29998    30000.0  ...    3100.0                           1
# 29998  29999    80000.0  ...    1804.0                           1
# 29999  30000    50000.0  ...    1000.0                           1
#
# [30000 rows x 24 columns]

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           2
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default.payment.next.month    0
# dtype: int64

# %%
df['AGE'].mean()
df=df.fillna({'AGE':35})

# %%
y = df['default.payment.next.month']
x=df.drop(['default.payment.next.month'],axis=1)

# %%
y
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 29995    0
# 29996    0
# 29997    1
# 29998    1
# 29999    1
# Name: default.payment.next.month, Length: 30000, dtype: int64

# %%
x
# Out:
#           ID  LIMIT_BAL  EDUCATION  ...  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 0          1    20000.0          2  ...       0.0       0.0       0.0
# 1          2   120000.0          2  ...    1000.0       0.0    2000.0
# 2          3    90000.0          2  ...    1000.0    1000.0    5000.0
# 3          4    50000.0          2  ...    1100.0    1069.0    1000.0
# 4          5    50000.0          2  ...    9000.0     689.0     679.0
# ...      ...        ...        ...  ...       ...       ...       ...
# 29995  29996   220000.0          3  ...    3047.0    5000.0    1000.0
# 29996  29997   150000.0          3  ...     129.0       0.0       0.0
# 29997  29998    30000.0          2  ...    4200.0    2000.0    3100.0
# 29998  29999    80000.0          3  ...    1926.0   52964.0    1804.0
# 29999  30000    50000.0          2  ...    1000.0    1000.0    1000.0
#
# [30000 rows x 23 columns]

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default.payment.next.month    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,y,train_size=0.75, test_size=0.25, random_state=50)

# %%
#import SVC
from sklearn.svm import SVC
Model= SVC(gamma="auto")

# %%
Model.fit(x_train,y_train)
Model.score(x_test,y_test)
# Out:
# 0.7865333333333333

# %%
#import confusion matrix
from sklearn.metrics import confusion_matrix
y_predict = Model.predict(x_test)

# %%
confusion_matrix(y_test,y_predict)
# Out:
# array([[5899,    0],
#        [1601,    0]])

# %%
#classification Report
from sklearn.metrics import classification_report
print (classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      1.00      0.88      5899
#            1       0.00      0.00      0.00      1601
#
#     accuracy                           0.79      7500
#    macro avg       0.39      0.50      0.44      7500
# weighted avg       0.62      0.79      0.69      7500
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
